# %%
import pandas as pd
import os
from tqdm import tqdm

# %%
dict = {}

# %%
files = os.listdir('/Users/danilakokin/Desktop/UPC/Semester2/SDM/SDM_Project/joined')

# %%
for filename in tqdm(files):
    df = pd.read_csv(f'joined/{filename}', low_memory=False)
    dict[filename[:-4]] = df
# Out:
# 100%|██████████| 9/9 [01:10<00:00,  7.83s/it]

# %%
dict.keys()
# Out:
# dict_keys(['www', 'inproceedings', 'article', 'proceedings', 'data', 'incollection', 'mastersthesis', 'book', 'phdthesis'])

# %%
dict['article']
# Out:
#          Unnamed: 0  article:ID  \
# 0                 0       32791
# 1                 1       32792
# 2                 2       32793
# 3                 3      678790
# 4                 4     2650352
# ...             ...         ...
# 3424242     3424242    10597988
# 3424243     3424243    10597989
# 3424244     3424244    10597990
# 3424245     3424245    10597991
# 3424246     3424246    10597992
#
#                                            author:string[] author-aux:string  \
# 0                                                      NaN               NaN
# 1                                                      NaN               NaN
# 2                                                      NaN               NaN
# 3                                             Emilio Coppa               NaN
# 4        Bart Verheecke|Davy Suvée|María Agustina Cibrá...               NaN
# ...                                                    ...               ...
# ...

# %%
dict['www']
# Out:
#          Unnamed: 0    www:ID  \
# 0                 0   3528210
# 1                 1   3528211
# 2                 2   3528212
# 3                 3   3528213
# 4                 4   3528214
# ...             ...       ...
# 3463082     3463082  10428910
# 3463083     3463083  10428911
# 3463084     3463084  10428912
# 3463085     3463085  10597979
# 3463086     3463086  10597982
#
#                                            author:string[]  \
# 0        Joaquim Macedo 0002|Joaquim Miguel Gonçalves M...
# 1                                          T. J. Grebinski
# 2                                             Aharon Abadi
# 3                                      Muhammad Naeem 0002
# 4                                           Killian Meehan
# ...                                                    ...
# 3463082                                        Robin Cover
# 3463083                                                NaN
# ...

# %%
dict['inproceedings']
# Out:
#          Unnamed: 0  inproceedings:ID  \
# 0                 0             37735
# 1                 1             37736
# 2                 2             37738
# 3                 3             37744
# 4                 4             37753
# ...             ...               ...
# 3429391     3429391          10465043
# 3429392     3429392          10465245
# 3429393     3429393          10465912
# 3429394     3429394          10466085
# 3429395     3429395          10597987
#
#                                            author:string[]  \
# 0                                                Sam Freed
# 1                                           Pierre Steiner
# 2                                          Anders Sandberg
# 3                     Claiborne Rice|Istvan S. N. Berkeley
# 4                      John Mark Bishop|Slawomir J. Nasuto
# ...                                                    ...
# 3429391  Chiori Hori|Hideki Kashioka|Kiyonori Ohtake|Ko...
# ...

# %%
dict['proceedings']
# Out:
#        Unnamed: 0  proceedings:ID address:string author:string[]  \
# 0               0            5760            NaN             NaN
# 1               1           15227            NaN             NaN
# 2               2           35397            NaN             NaN
# 3               3           37823            NaN             NaN
# 4               4           37902            NaN             NaN
# ...           ...             ...            ...             ...
# 57684       57684        10442146            NaN             NaN
# 57685       57685        10442194            NaN             NaN
# 57686       57686        10447748            NaN             NaN
# 57687       57687        10460358            NaN             NaN
# 57688       57688        10597618            NaN             NaN
#
#                                         booktitle:string cite:string[]  \
# 0                                                    NaN           NaN
# ...

# %%
dict['incollection']
# Out:
#        Unnamed: 0  incollection:ID  \
# 0               0                0
# 1               1                1
# 2               2                2
# 3               3                3
# 4               4                4
# ...           ...              ...
# 70309       70309         10470038
# 70310       70310         10470039
# 70311       70311         10470040
# 70312       70312         10470041
# 70313       70313         10470042
#
#                                          author:string[]  \
# 0                                                    NaN
# 1                                      Manish Singh 0001
# 2                                                    NaN
# 3                                                    NaN
# 4                                         Tien-Tsin Wong
# ...                                                  ...
# 70309  Christian S. Jensen|Nectaria Tryfona|Rosanne P...
# 70310          André Flory|Madjid Meziane|Youssef Amghar
# ...

# %%
dict['mastersthesis']
# Out:
#     Unnamed: 0  mastersthesis:ID                      author:string  \
# 0            0             28078                   Vanessa C. Klaas
# 1            1             28079                           Rita Ley
# 2            2             28080                        Tolga Yurek
# 3            3             28081               Oliver Hoffmann 0002
# 4            4             28082                    Stephan Vollmer
# 5            5             28083                      Kurt P. Brown
# 6            6          10472722                          Liang Dai
# 7            7          10486543                       Salim Perchy
# 8            8          10496438                   Martin Monperrus
# 9            9          10499619                        Leo Liberti
# 10          10          10505708                    Satyan R. Coorg
# 11          11          10508865               Rodrigo Pastl Pontes
# 12          12          10521724                           Jiwei Li
# ...

# %%
dict['book']
# Out:
#        Unnamed: 0   book:ID  author:string[] author-bibtex:string  \
# 0               0       319              NaN                  NaN
# 1               1       895              NaN                  NaN
# 2               2      2011              NaN                  NaN
# 3               3      2020              NaN                  NaN
# 4               4      2910              NaN                  NaN
# ...           ...       ...              ...                  ...
# 20415       20415  10597189              NaN                  NaN
# 20416       20416  10597740              NaN                  NaN
# 20417       20417  10597742              NaN                  NaN
# 20418       20418  10597744  Uwe M. Borghoff                  NaN
# 20419       20419  10597985       John Lions                  NaN
#
#       author-orcid:string[]                       booktitle:string  \
# 0                       NaN     Computer Vision, A Reference Guide
# ...

# %%
dict['phdthesis']
# Out:
#         Unnamed: 0  phdthesis:ID     author:string[]  author-orcid:string  \
# 0                0         37907  Pavlos Vougiouklis                  NaN
# 1                1         37983       Ingo M. Weber  0000-0002-4833-5921
# 2                2         40767   Kristian Kersting                  NaN
# 3                3      10438151  Vladislav Golyanik                  NaN
# 4                4      10440322      Mohammed Rajab                  NaN
# ...            ...           ...                 ...                  ...
# 128106      128106      10597172       Sanjai Narain                  NaN
# 128107      128107      10597173    Ann L. Chervenak                  NaN
# 128108      128108      10597174            Asit Dan                  NaN
# 128109      128109      10597175      Christof Hasse                  NaN
# 128110      128110      10597176   Viswanath Poosala                  NaN
#
#                                               ee:string[] ee-type:string[]  \
# ...
